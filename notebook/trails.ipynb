# %% [markdown]
# # Build the FRAUD MODEL (Offline ML Development)**
#
# ### Tasks:
#
# * Create a sample dataset (transactions + labels)
# * Train baseline fraud model (XGBoost, RandomForest, or LightGBM)
# * Save model to **MLflow Model Registry**
# * Log:
#
#   * parameters
#   * metrics
#   * artifacts
#   * models
#
# ### Test:
#
# * Load model from MLflow and run prediction on sample data
# * Validate latency (<5 ms per transaction expected)

# %%
import pandas as pd
import numpy as np
import datetime as dt

# %%
df_customer = pd.read_csv("../data/customer.csv")
df_transaction = pd.read_csv("../data/transactions.csv")

print(df_customer.columns)
print(df_transaction.columns)
# Out:
# Index(['cc_num', 'first', 'last', 'gender', 'street', 'city', 'state', 'zip',
#        'lat', 'long', 'job', 'dob'],
#       dtype='object')
# Index(['cc_num', 'first', 'last', 'trans_num', 'trans_date', 'trans_time',
#        'unix_time', 'category', 'merchant', 'amt', 'merch_lat', 'merch_long',
#        'is_fraud'],
#       dtype='object')

# %%
# merge the dataset
df_transaction = df_transaction.drop(columns=['first','last'],axis=1)
df = pd.merge(df_transaction, df_customer, how='left', on='cc_num')
df.columns
# Out:
# Index(['cc_num', 'trans_num', 'trans_date', 'trans_time', 'unix_time',
#        'category', 'merchant', 'amt', 'merch_lat', 'merch_long', 'is_fraud',
#        'first', 'last', 'gender', 'street', 'city', 'state', 'zip', 'lat',
#        'long', 'job', 'dob'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11871 entries, 0 to 11870
# Data columns (total 22 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   cc_num      11871 non-null  int64
#  1   trans_num   11871 non-null  object
#  2   trans_date  11871 non-null  object
#  3   trans_time  11871 non-null  object
#  4   unix_time   11871 non-null  int64
#  5   category    11871 non-null  object
#  6   merchant    11871 non-null  object
#  7   amt         11871 non-null  int64
#  8   merch_lat   11871 non-null  float64
#  9   merch_long  11871 non-null  float64
#  10  is_fraud    11871 non-null  int64
#  11  first       11871 non-null  object
#  12  last        11871 non-null  object
#  13  gender      11871 non-null  object
#  14  street      11871 non-null  object
#  15  city        11871 non-null  object
#  16  state       11871 non-null  object
#  17  zip         11871 non-null  int64
#  18  lat         11871 non-null  float64
#  19  long        11871 non-null  float64
#  20  job         11871 non-null  object
#  21  dob         11871 non-null  object
# dtypes: float64(4), int64(5), object(13)
# memory usage: 2.0+ MB

# %%
df.head()
# Out:
#              cc_num                         trans_num  \
# 0   180094108369013  80f5177be11f0bcd768e06a0b1b294c8
# 1  4368593032190508  7933d389bf8ef8a11a8a301da6e6bc6c
# 2     4361355512072  1467c318b5d73d22d6741f575db42f3f
# 3  4037295225657274  4a3848719d72daaa32c938ce43e0eb03
# 4  4515092388857440  02d27e94f279e1013a4c323eb8bb6811
#
#                       trans_date trans_time   unix_time       category  \
# 0  2012-01-01T00:00:00.000+05:30   00:12:15  1325376735  personal_care
# 1  2012-01-01T00:00:00.000+05:30   00:16:58  1325377018  gas_transport
# 2  2012-01-01T00:00:00.000+05:30   00:36:42  1325378202  entertainment
# 3  2012-01-01T00:00:00.000+05:30   00:37:59  1325378279   shopping_pos
# 4  2012-01-01T00:00:00.000+05:30   00:39:18  1325378358   shopping_pos
#
#                         merchant  amt  merch_lat  merch_long  ...     last  \
# 0                    Hills-Boyer   64  39.011566 -119.937831  ...  Holland
# 1                 Friesen-DAmore  133  40.149071  -75.589697  ...  Fleming
# 2                    Larson-Moen  119  47.297797  -96.819362  ...   Nelson
# 3                      Lynch Ltd   62  40.078781 -102.373954  ...   Garcia
# 4  Baumbach, Strosin and Nicolas  198  41.549359  -83.044403  ...    Silva
#
#   gender                     street          city state    zip      lat  \
# 0      M       630 Christina Harbor   Zephyr Cove    NV  89448  39.0204
# 1      F  9667 Brown Club Suite 507   Spring City    PA  19475  40.1765
# 2      M      13242 Jackson Landing       Hendrum    MN  56550  47.2689
# 3      M          2145 Chad Viaduct          Wray    CO  80758  40.0685
# 4      M          1339 Matthew View  Port Clinton    OH  43452  41.5583
#
#        long                                            job  \
# 0 -119.9114                     Geophysical data processor
# 1  -75.5697                             Engineer, chemical
# 2  -96.7988  Programme researcher, broadcasting/film/video
# 3 -102.3930                  Advertising account executive
# 4  -83.0502                      Psychologist, counselling
#
#                    dob
# 0  1949-12-28 13:30:00
# 1  1961-05-20 14:30:00
# 2  1987-07-13 14:30:00
# 3  1978-09-16 14:30:00
# 4  1939-04-28 13:07:00
#
# [5 rows x 22 columns]

# %%
df.describe()
# Out:
#              cc_num     unix_time           amt     merch_lat    merch_long  \
# count  1.187100e+04  1.187100e+04  11871.000000  11871.000000  11871.000000
# mean   3.133233e+15  1.433198e+09    150.597675     39.767213    -92.629963
# std    2.361177e+15  6.080565e+07    195.814267      5.567138     12.671022
# min    6.759852e+11  1.325377e+09     11.000000     26.319252   -125.437401
# 25%    4.483019e+12  1.451912e+09     71.000000     36.944888   -102.397248
# 50%    4.170243e+15  1.463510e+09    103.000000     41.870607    -92.162653
# 75%    5.157436e+15  1.471882e+09    163.000000     44.759263    -82.980032
# max    6.546851e+15  1.481233e+09   2786.000000     48.709398    -71.001628
#
#            is_fraud          zip           lat          long
# count  11871.000000  11871.00000  11871.000000  11871.000000
# mean       0.042204  53321.23629     39.768711    -92.635258
# std        0.201062  25557.65004      5.562462     12.671775
# min        0.000000   5476.00000     27.429500   -123.794500
# 25%        0.000000  39746.00000     36.957600   -102.393000
# 50%        0.000000  59323.00000     41.879800    -92.164400
# 75%        0.000000  78344.00000     44.769000    -82.987800
# max        1.000000  97302.00000     47.268900    -72.690500

# %%
df.shape
# Out:
# (11871, 22)

# %%
df.isna().sum()
# Out:
# cc_num        0
# trans_num     0
# trans_date    0
# trans_time    0
# unix_time     0
# category      0
# merchant      0
# amt           0
# merch_lat     0
# merch_long    0
# is_fraud      0
# first         0
# last          0
# gender        0
# street        0
# city          0
# state         0
# zip           0
# lat           0
# long          0
# job           0
# dob           0
# dtype: int64

# %%
len(df['trans_num'].unique())
# Out:
# 11871

# %% [markdown]
# ### drop columns:
# `first, last name of user,
# street name, trans_num`

# %%
df = df.drop(columns=['first','last', 'street','trans_num'])
df.columns
# Out:
# Index(['cc_num', 'trans_date', 'trans_time', 'unix_time', 'category',
#        'merchant', 'amt', 'merch_lat', 'merch_long', 'is_fraud', 'gender',
#        'city', 'state', 'zip', 'lat', 'long', 'job', 'dob'],
#       dtype='object')

# %% [markdown]
# ### Feature Engineering

# %%
categorical_col = ['cc_num','category', 'merchant','is_fraud', 'gender', 'state', 'job']
date_col = ['trans_date', 'dob']

# %%
df['dob'] = pd.to_datetime(df['dob']).dt.normalize()
df['trans_date'] = pd.to_datetime(df['trans_date']).dt.normalize()
df['age'] = df['trans_date'].dt.year - df['dob'].dt.year

categorical_col +=['age']

# %%
df['trans_time'] = pd.to_datetime(df['trans_time'])
df['trans_hour'] = df['trans_time'].dt.hour

categorical_col+=['trans_hour']

# %%
## find distance between user location and transaction location
# User coordinates
user_lat = df['lat']
user_long = df['long']

# Merchant coordinates
merch_lat = df['merch_lat']
merch_long = df['merch_long']

# Convert degrees to radians
lat1 = np.radians(user_lat)
lon1 = np.radians(user_long)
lat2 = np.radians(merch_lat)
lon2 = np.radians(merch_long)

# Haversine formula
dlat = lat2 - lat1
dlon = lon2 - lon1

a = np.sin(dlat/2)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon/2)**2
c = 2 * np.arcsin(np.sqrt(a))

R = 6371  # Earth radius in km

df['distance_km'] = R * c
df['distance_km'].describe()
# Out:
# count    11871.000000
# mean         7.059771
# std         28.558318
# min          0.015227
# 25%          1.021778
# 50%          1.452968
# 75%          1.878533
# max        244.447039
# Name: distance_km, dtype: float64

# %%
for col in categorical_col:
    print(df[col].value_counts())
# Out:
# cc_num
# 4641003399120410    2016
# 675985166411        1971
# 4170242670039985    1340
# 5157595343543285    1308
# 6011779269963768    1023
# 4483018920250        996
# 4361646620879135     329
# 5421885738881170     198
# 4037295225657274     163
# 4354778868658084     156
# 370763211656868      147
# 180094108369013      127
# 6011537727192499     126
# 3593533875650654     120
# 5157436163845247     105
# 6011165671471311     102
# 3526015186182660     101
# 3561758568398109      97
# 38535403302699        97
# 4006862159277         97
# 4765125568595799      70
# 349326734419590       70
# 4361355512072         70
# 30157941709315        69
# 4368593032190508      69
# 30300776786251        69
# 4515092388857440      69
# 180036251237802       69
# 348933408404369       67
# 4738555317386146      65
# 4550801576257         64
# 30260722249657        46
# 5132731018032805      42
# 30021746099829        41
# 374115112731710       39
# 30170394853324        39
# 5264302655249852      39
# 30405027360515        39
# 4092259246729         38
# 5590294502817012      37
# 6011047554247853      37
# 342823590771707       37
# 6546851067101927      12
# 5417459284978545      11
# 341559343212109       10
# 676165681542          10
# 379684560931689       10
# 676331132040           7
# 4048725581466255       7
# Name: count, dtype: int64
# category
# gas_transport     1544
# grocery_pos       1201
# shopping_pos      1124
# home              1066
# kids_pets          966
# shopping_net       925
# personal_care      865
# misc_pos           762
# food_dining        745
# entertainment      714
# health_fitness     704
# misc_net           602
# grocery_net        353
# travel             300
# Name: count, dtype: int64
# merchant
# Bartoletti-Wunsch                46
# Kutch LLC                        40
# Cormier LLC                      40
# Harber Inc                       38
# Berge LLC                        38
#                                  ..
# Skiles-Ankunding                  3
# Morar Inc                         3
# Kilback, Nitzsche and Leffler     3
# Spinka Inc                        2
# Tillman LLC                       2
# Name: count, Length: 693, dtype: int64
# is_fraud
# 0    11370
# 1      501
# Name: count, dtype: int64
# gender
# F    10016
# M     1855
# Name: count, dtype: int64
# city
# Garrison          2016
# Madrid            1971
# Colstrip          1340
# Bruni             1308
# Catron            1023
# La Plata           996
# Kiamesha Lake      329
# Chicago            310
# Lewis Center       198
# Wray               163
# Zephyr Cove        127
# Lansing            126
# Oswego             120
# Bakersfield        105
# San Francisco      102
# Hathaway Pines     101
# London              97
# Paterson            97
# Brooklyn            97
# Sperryville         70
# Thayer              70
# Hendrum             70
# Salt Lick           69
# Spring City         69
# Francitas           69
# Port Clinton        69
# Caledonia           69
# Dublin              67
# Florence            65
# Erie                64
# Canton              46
# Lemitar             42
# Elk Point           41
# Savannah            39
# Goldfield           39
# Myers Flat          39
# Hamilton            39
# Sperry              38
# Charlotte           37
# Burnet              37
# Orlando             37
# Peoria              12
# Livonia             11
# Terre Haute         10
# Salem               10
# Ashland             10
# Richford             7
# Name: count, dtype: int64
# state
# NY    2447
# IA    2054
# TX    1414
# MT    1340
# NM    1038
# MO    1023
# IL     442
# OH     364
# CA     347
# KS     196
# NV     166
# CO     163
# MN     139
# PA     133
# NJ      97
# VA      70
# KY      69
# GA      67
# AL      65
# MI      46
# SD      41
# MS      39
# NC      37
# FL      37
# NE      10
# OR      10
# IN      10
# VT       7
# Name: count, dtype: int64
# job
# Human resources officer                          2026
# Building surveyor                                2008
# Air broker                                       1340
# Senior tax professional/tax inspector            1308
# Personnel officer                                1023
# Engineer, electronics                             996
# Copy                                              329
# Designer, industrial/product                      198
# Advertising account executive                     163
# Technical author                                  156
# Nurse, adult                                      147
# Geophysical data processor                        127
# Producer, radio                                   126
# Magazine features editor                          120
# Archivist                                         105
# Arts development officer                          102
# Data processing manager                           101
# Insurance risk surveyor                            97
# Electronics engineer                               97
# Tourism officer                                    97
# Clinical biochemist                                70
# Programme researcher, broadcasting/film/video      70
# Leisure centre manager                             70
# Psychologist, counselling                          69
# Engineer, civil (contracting)                      69
# Hydrographic surveyor                              69
# Psychologist, forensic                             69
# Engineer, chemical                                 69
# Purchasing manager                                 67
# Osteopath                                          65
# Administrator, sports                              64
# Teacher, special educational needs                 46
# Private music teacher                              42
# Chiropractor                                       41
# Designer, fashion/clothing                         39
# Scientist, physiological                           39
# Data scientist                                     39
# Engineer, control and instrumentation              39
# Conservation officer, nature                       38
# Television camera operator                         37
# Accountant, chartered public finance               37
# Event organiser                                    12
# Landscape architect                                11
# Education administrator                            10
# Editor, film/video                                 10
# Retail banker                                       7
# Wellsite geologist                                  7
# Name: count, dtype: int64
# age
# 39    2124
# 41    1971
# 43    1345
# 33    1340
# 36    1170
# 27     996
# 42     426
# 34     202
# 54     198
# 17     198
# 63     169
# 29     156
# 30     135
# 40     126
# 18     120
# 21     105
# 72     104
# 53     102
# 55      97
# 70      80
# 57      75
# 25      70
# 38      69
# 51      69
# 73      69
# 56      69
# 14      46
# 59      41
# 64      39
# 88      39
# 52      38
# 61      37
# 83      12
# 58      10
# 67      10
# 46       7
# 62       7
# Name: count, dtype: int64
# trans_hour
# 22    773
# 23    756
# 17    707
# 20    690
# 16    671
# 12    670
# 21    645
# 19    634
# 18    632
# 15    613
# 13    613
# 14    609
# 3     362
# 9     348
# 2     347
# 0     336
# 6     333
# 1     332
# 8     322
# 5     314
# 11    309
# 7     296
# 10    295
# 4     264
# Name: count, dtype: int64

# %% [markdown]
# ### Analysis

# %% [markdown]
# ### Model Training

# %% [markdown]
# 1. Feature selection
#
# 2. Model training
#
# 3. Evaluation
#
# 4. store model

# %%
df.columns
# Out:
# Index(['cc_num', 'trans_date', 'trans_time', 'unix_time', 'category',
#        'merchant', 'amt', 'merch_lat', 'merch_long', 'is_fraud', 'gender',
#        'city', 'state', 'zip', 'lat', 'long', 'job', 'dob', 'age',
#        'trans_hour', 'distance_km'],
#       dtype='object')

# %%
selected_column = ['category', 'gender', 'state','trans_hour', 'amt', 'distance_km', 'age','is_fraud']
df_final = df[selected_column]

# %%
### Train test split
from sklearn.model_selection import train_test_split

X = df_final.drop(['is_fraud'],axis=1)
y = df_final['is_fraud']

X_train, X_test, y_train, y_test = train_test_split(X, 
    y, 
    test_size=0.2,      # 20% test
    random_state=42,    # reproducible
    stratify=y          # keep fraud balance
)
X_train.shape
# Out:
# (9496, 7)

# %%
cat_cols = ['category', 'gender', 'state' ]
num_cols = ['amt', 'distance_km', 'age']
target_col = ['is_fraud']

# %%
# convert category into one hot encoding - gender, catrgory, stage

from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
import joblib

cat_cols = ['category', 'gender', 'state']

# 1. Create the encoder
ohe = OneHotEncoder(handle_unknown='ignore', sparse_output=False)

# 2. Build the ColumnTransformer
preprocessor = ColumnTransformer(
    transformers=[
        ('ohe', ohe, cat_cols)
    ],
    remainder='passthrough'   # keep other columns as is
)

# 3. Fit and transform the data
# train_encoded = preprocessor.fit_transform(X_train[cat_cols])
# X_train = X_train.drop(cat_cols)
# X_train = pd.concat([X_train, train_encoded])

preprocessor.fit(df_final[cat_cols])
X_train_encoded = preprocessor.transform(X_train)
X_test_encoded = preprocessor.transform(X_test)


joblib.dump(preprocessor, "../artifacts/onehot_encoder.pkl")
# Out:
# ['../artifacts/onehot_encoder.pkl']

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from xgboost import XGBClassifier

from sklearn.metrics import accuracy_score, f1_score

# --------------------------------------
# TRAIN MULTIPLE MODELS
# --------------------------------------

models = {
    "LogisticRegression": LogisticRegression(max_iter=300),
    "RandomForest": RandomForestClassifier(n_estimators=300, random_state=42),
    "GradientBoosting": GradientBoostingClassifier(random_state=42),
    "XGBoost": XGBClassifier(
        n_estimators=300,
        learning_rate=0.05,
        max_depth=5,
        subsample=0.9,
        colsample_bytree=0.9,
        eval_metric="logloss",
        random_state=42
    )
}

results = {}
best_model = None
best_score = -np.inf
best_model_name = ""

# --------------------------------------
# TRAIN + EVALUATE MODELS
# --------------------------------------
for name, model in models.items():
    print(f"Training: {name}")
    model.fit(X_train_encoded, y_train)

    y_pred = model.predict(X_test_encoded)

    acc = accuracy_score(y_test, y_pred)
    f1  = f1_score(y_test, y_pred)

    results[name] = {"accuracy": acc, "f1_score": f1}

    print(f"{name} → Accuracy: {acc:.4f}, F1: {f1:.4f}")

    # Select best by F1 (recommended for fraud)
    if f1 > best_score:
        best_model = model
        best_score = f1
        best_model_name = name

# --------------------------------------
# SHOW RESULTS
# --------------------------------------
print("\n=== Model Comparison ===")
for name, metrics in results.items():
    print(f"{name}: {metrics}")

print(f"\nBest Model: {best_model_name}  (F1 = {best_score:.4f})")

# --------------------------------------
# SAVE BEST MODEL
# --------------------------------------
joblib.dump(best_model, "../artifacts/best_model.pkl")
print(f"\nSaved best model as best_model.pkl")
# Out:
# Training: LogisticRegression
# LogisticRegression → Accuracy: 0.9583, F1: 0.1081
# Training: RandomForest
# RandomForest → Accuracy: 0.9579, F1: 0.2857
# Training: GradientBoosting
# GradientBoosting → Accuracy: 0.9592, F1: 0.2362
# Training: XGBoost
# XGBoost → Accuracy: 0.9575, F1: 0.2406
#
# === Model Comparison ===
# LogisticRegression: {'accuracy': 0.9583157894736842, 'f1_score': 0.10810810810810811}
# RandomForest: {'accuracy': 0.9578947368421052, 'f1_score': 0.2857142857142857}
# GradientBoosting: {'accuracy': 0.9591578947368421, 'f1_score': 0.23622047244094488}
# XGBoost: {'accuracy': 0.9574736842105264, 'f1_score': 0.24060150375939848}
#
# Best Model: RandomForest  (F1 = 0.2857)
#
# Saved best model as best_model.pkl
